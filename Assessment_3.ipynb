# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import IPython
from IPython.display import Image

# %%
Image("C:/Users/Chandrika/Documents/codegnan/Data Analysis/archive/netflix img.png")

# %%
file_path = "C:/Users/Chandrika/Documents/codegnan/Data Analysis/archive/netflix_titles_2021.csv" 
netflix = pd.read_csv(file_path)

# %% [markdown]
# ### 1) Understanding the Dataset

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
netflix.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
netflix.sample()
# Out:
#      show_id   type             title       director         cast country  \
# 2182   s2183  Movie  Tumi or not Tumi  Mfanelo Ngoma  Tumi Morake     NaN
#
#           date_added  release_year rating duration        listed_in  \
# 2182  August 1, 2020          2020  TV-MA   72 min  Stand-Up Comedy
#
#                                             description
# 2182  Tumi Morake dishes out hot takes and fiery com...

# %%
netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
netflix.shape
# Out:
# (8807, 12)

# %%
netflix.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
netflix.describe(include = 'all')
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
# mean       NaN    NaN                   NaN            NaN
# std        NaN    NaN                   NaN            NaN
# min        NaN    NaN                   NaN            NaN
# 25%        NaN    NaN                   NaN            NaN
# 50%        NaN    NaN                   NaN            NaN
# 75%        NaN    NaN                   NaN            NaN
# max        NaN    NaN                   NaN            NaN
#
#                       cast        country       date_added  release_year  \
# count                 7982           7976             8797   8807.000000
# unique                7692            748             1767           NaN
# ...

# %%
netflix.select_dtypes(include = 'int64')
# Out:
#       release_year
# 0             2020
# 1             2021
# 2             2021
# 3             2021
# 4             2021
# ...            ...
# 8802          2007
# 8803          2018
# 8804          2009
# 8805          2006
# 8806          2015
#
# [8807 rows x 1 columns]

# %%
netflix.select_dtypes(include = 'object').columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
netflix.loc[:]
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix.iloc[3 : 11 ,[3 , 4]]
# Out:
#                          director  \
# 3                             NaN
# 4                             NaN
# 5                   Mike Flanagan
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 8                 Andy Devonshire
# 9                  Theodore Melfi
# 10                            NaN
#
#                                                  cast
# 3                                                 NaN
# 4   Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5   Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 10                                                NaN

# %% [markdown]
# ### 2) Distribution of Netflix Content Type

# %%
sns.countplot(x = 'type', data = netflix)
plt.title('Distribution of Netflix Content Types')
plt.show()

# %% [markdown]
# ### 3) Correlation b/w the features

# %%
numerical_columns = netflix.select_dtypes(include=['int64', 'float64'])

# Compute the correlation matrix
correlation_matrix = numerical_columns.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#               release_year
# release_year           1.0

# %% [markdown]
# ### 4) Most Watched Shows On Netflix

# %%
type_show = ['Movie', 'TV Show']
value_counts = [5522, 178]
plt.pie(value_counts, labels = type_show, autopct = '%2.2f%%')
plt.legend('Most Watched Shows On Netflix')
plt.show()

# %% [markdown]
# ### 5) Distribution of Content Ratings

# %%
plt.figure(figsize = (15,8))
sns.countplot(x = 'rating', data = netflix, order = netflix['rating'].value_counts().index)
plt.title('Distribution of Content Ratings')
plt.show()

# %% [markdown]
# ### 6) Which has the highest rating tv show or movies ?

# %%
netflix.groupby('type')['rating'].value_counts().unstack().plot(kind = 'bar', figsize = (10,5), colormap = 'coolwarm')
plt.show()

# %% [markdown]
# ### 7) Finding the best month for releasing content?

# %%
netflix['date_added'].mode()
# Out:
# 0    January 1, 2020
# Name: date_added, dtype: object

# %% [markdown]
# ### 8) Highest rating TV Show or Movie?

# %%
print("Unique values in 'rating' column before cleaning:")
print(netflix['rating'].unique())
# Out:
# Unique values in 'rating' column before cleaning:
# ['PG-13' 'TV-MA' 'PG' 'TV-14' 'TV-PG' 'TV-Y' 'TV-Y7' 'R' 'TV-G' 'G'
#  'NC-17' '74 min' '84 min' '66 min' 'NR' nan 'TV-Y7-FV' 'UR']

# %% [markdown]
# ### 9) Released Movie Over the years?

# %%
movies = netflix[netflix['type'] == 'Movie']

# Group by 'release_year' and count the number of movies
movies_per_year = movies.groupby('release_year').size().reset_index(name='count')

# Display the result
print(movies_per_year)

# Optional: Visualize the trend
plt.figure(figsize=(12, 6))
plt.plot(movies_per_year['release_year'], movies_per_year['count'], marker='o', linestyle='-')
plt.title('Number of Movies Released Over the Years')
plt.xlabel('Release Year')
plt.ylabel('Number of Movies')
plt.grid(True)
plt.show()
# Out:
#     release_year  count
# 0           1942      2
# 1           1943      3
# 2           1944      3
# 3           1945      3
# 4           1946      1
# ..           ...    ...
# 68          2017    767
# 69          2018    767
# 70          2019    633
# 71          2020    517
# 72          2021    277
#
# [73 rows x 2 columns]

# %% [markdown]
# ### 10) Movies made on year basis?

# %%
# Filter for movies only
movies = netflix[netflix['type'] == 'Movie']

# Group by 'release_year' and count the number of movies
movies_per_year = movies.groupby('release_year').size().reset_index(name='count')

# Create a line plot
plt.figure(figsize=(12, 6))
sns.lineplot(x='release_year', y='count', data=movies_per_year, marker='o', color='b')
plt.title('Number of Movies Released Over the Years')
plt.xlabel('Release Year')
plt.ylabel('Number of Movies')
plt.grid(True)
plt.show()

# %%
# Alternatively, create a bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x='release_year', y='count', data=movies_per_year, palette='viridis')
plt.title('Number of Movies Released Over the Years')
plt.xlabel('Release Year')
plt.ylabel('Number of Movies')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# ### 11) show_id and director for house of cards?

# %%
house_of_cards_info = netflix[netflix['title'] == 'House of Cards']

# Display show_id and director
print(house_of_cards_info[['show_id', 'director']])
# Out:
#      show_id director
# 1059   s1060      NaN

# %% [markdown]
# ### 12) Show all the movies that were released in year 2000.

# %%
movies_2000 = netflix[(netflix['type'] == 'Movie') & (netflix['release_year'] == 2000)]

# Display the results
print(movies_2000[['title', 'release_year']])
# Out:
#                                                   title  release_year
# 180                  The Nutty Professor II: The Klumps          2000
# 350                                       Space Cowboys          2000
# 359                        The Original Kings of Comedy          2000
# 566                                    Charlie's Angels          2000
# 593                                            Snow Day          2000
# 779                                   Battlefield Earth          2000
# 952                                The Whole Nine Yards          2000
# 3472                        Rugrats in Paris: The Movie          2000
# 4545             Monty Python: Before the Flying Circus          2000
# 4723                                               Fiza          2000
# 4956                        Phir Bhi Dil Hai Hindustani          2000
# 5953                             Joseph: King of Dreams          2000
# ...

# %% [markdown]
# ### 13 Show only the title of all tv shows that were released in india only

# %%
# Filter for TV shows released in India
india_tv_shows = netflix[(netflix['type'] == 'TV Show') & (netflix['country'] == 'India')]

# Display the titles of the TV shows
print(india_tv_shows['title'])
# Out:
# 4                             Kota Factory
# 39                            Chhota Bheem
# 50                           Dharmakshetra
# 66           Raja Rasoi Aur Anya Kahaniyan
# 69          Stories by Rabindranath Tagore
#                        ...
# 8173                             Thackeray
# 8235                           The Calling
# 8321    The Golden Years with Javed Akhtar
# 8349                The House That Made Me
# 8775                       Yeh Meri Family
# Name: title, Length: 79, dtype: object

# %%
india_tv_shows = netflix[(netflix['type'] == 'TV Show') & (netflix['country'] == 'India')]

# Extract the titles
titles = india_tv_shows['title']

# Create a horizontal bar plot
plt.figure(figsize=(10, len(titles) * 0.5))  # Adjust figure size based on the number of titles
sns.barplot(x=[1] * len(titles), y=titles, palette='viridis', orient='h')
plt.title('TV Shows Released in India')
plt.xlabel('')  # Remove x-axis label
plt.ylabel('Title')  # Label for y-axis
plt.xticks([])  # Remove x-axis ticks
plt.show()

# %% [markdown]
# ### 14) show Top 10 Directors who gave the highest number of tv shows and movies to netflix?

# %%
content = netflix['director'].value_counts().head(10)

sns.barplot(y = content.index, x = content.values)
plt.title("Top 10 Directors Producing Most Netflix Content")
plt.show()

# %% [markdown]
# ### 15) in how many movies / tv shows , tom cruise was cast?

# %%
tom_cruise_movies_shows = netflix[netflix['cast'].str.contains('Tom Cruise', case=False, na=False)]

# Count the number of movies/TV shows
count = tom_cruise_movies_shows.shape[0]

# Display the result
print(f"Tom Cruise was cast in {count} movies/TV shows.")
# Out:
# Tom Cruise was cast in 2 movies/TV shows.

# %% [markdown]
# ### 16) how many movies got the Tv-14 rating in the canada?

# %%
# Filter for movies with TV-14 rating released in Canada
tv14_canada_movies = netflix[(netflix['type'] == 'Movie') & 
                             (netflix['rating'] == 'TV-14') & 
                             (netflix['country'] == 'Canada')]

# Count the number of movies
count = tv14_canada_movies.shape[0]

# Display the result
print(f"Number of movies with TV-14 rating released in Canada: {count}")
# Out:
# Number of movies with TV-14 rating released in Canada: 13

# %%
rating_counts = netflix[(netflix['type'] == 'Movie') & (netflix['country'] == 'Canada')]['rating'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(rating_counts, labels=rating_counts.index,rotatelabels = True,  autopct='%1.1f%%', startangle=90, colors=sns.color_palette('viridis'))
plt.title('Distribution of Movie Ratings in Canada')
plt.show()
